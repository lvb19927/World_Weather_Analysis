# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
# Import the requests library
import requests
import random
# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low =-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %%
# #for testing
# cities=cities[:5]
# len(cities)

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
#Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log the URL, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    #Add 1 to the record count.
    
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()

           # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]


        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_description
                         })

        # If an error is experienced, skip the city
    except:
        print("City not found...")
    pass

 

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | bambous virieux
# Processing Record 5 of Set 1 | hamilton
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | nortelandia
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | seoul
# Processing Record 10 of Set 1 | gushikawa
# Processing Record 11 of Set 1 | samusu
# City not found...
# Processing Record 12 of Set 1 | te anau
# Processing Record 13 of Set 1 | ambon
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | nouadhibou
# Processing Record 16 of Set 1 | kolokani
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | eichenzell
# Processing Record 19 of Set 1 | abu samrah
# Processing Record 20 of Set 1 | sonoita
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | ahipara
# Processing Record 25 of Set 1 | kupang
# Processing Record 26 of Set 1 | salalah
# Processing Record 27 of Set 1 | lovozero
# Processing Record 28 of Set 1 | torzhok
# Processing Record 29 of Set 1 | vyshneve
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | moses lake
# Processing Record 32 of Set 1 | faya
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | coromandel
# Processing Record 35 of Set 1 | jaisalmer
# Processing Record 36 of Set 1 | daru
# Processing Record 37 of Set 1 | tura
# Processing Record 38 of Set 1 | taolanaro
# City not found...
# Processing Record 39 of Set 1 | blackwater
# Processing Record 40 of Set 1 | chuy
# Processing Record 41 of Set 1 | taoudenni
# Processing Record 42 of Set 1 | grand gaube
# Processing Record 43 of Set 1 | vila franca do campo
# Processing Record 44 of Set 1 | bathsheba
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | astana
# Processing Record 47 of Set 1 | dera din panah
# City not found...
# Processing Record 48 of Set 1 | kaitangata
# Processing Record 49 of Set 1 | waddan
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | portland
# Processing Record 4 of Set 2 | sakakah
# Processing Record 5 of Set 2 | nuuk
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | raymore
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | kamaishi
# Processing Record 10 of Set 2 | cedar city
# Processing Record 11 of Set 2 | upernavik
# Processing Record 12 of Set 2 | nanortalik
# Processing Record 13 of Set 2 | hambantota
# Processing Record 14 of Set 2 | longyearbyen
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | isangel
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | pevek
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | aksarka
# Processing Record 24 of Set 2 | roscommon
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | tuktoyaktuk
# Processing Record 27 of Set 2 | tateyama
# Processing Record 28 of Set 2 | mount isa
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | porto santo
# Processing Record 32 of Set 2 | thayetmyo
# Processing Record 33 of Set 2 | najran
# Processing Record 34 of Set 2 | sibolga
# Processing Record 35 of Set 2 | sumbawa
# City not found...
# Processing Record 36 of Set 2 | mocuba
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | mporokoso
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | port elizabeth
# Processing Record 42 of Set 2 | jalu
# Processing Record 43 of Set 2 | muisne
# Processing Record 44 of Set 2 | vardo
# Processing Record 45 of Set 2 | tabou
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | okhotsk
# Processing Record 48 of Set 2 | tuatapere
# Processing Record 49 of Set 2 | port lincoln
# Processing Record 50 of Set 2 | caravelas
# Processing Record 1 of Set 3 | sobolevo
# Processing Record 2 of Set 3 | erdenet
# Processing Record 3 of Set 3 | quesnel
# Processing Record 4 of Set 3 | lata
# Processing Record 5 of Set 3 | puerto madryn
# Processing Record 6 of Set 3 | marsala
# Processing Record 7 of Set 3 | cornwall
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | jamestown
# Processing Record 10 of Set 3 | kruisfontein
# Processing Record 11 of Set 3 | bandarbeyla
# Processing Record 12 of Set 3 | ribeira grande
# Processing Record 13 of Set 3 | toora-khem
# Processing Record 14 of Set 3 | bethel
# Processing Record 15 of Set 3 | nelson
# Processing Record 16 of Set 3 | fortuna
# Processing Record 17 of Set 3 | atuona
# Processing Record 18 of Set 3 | khatanga
# Processing Record 19 of Set 3 | sayat
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | masterton
# Processing Record 23 of Set 3 | geraldton
# Processing Record 24 of Set 3 | gagra
# Processing Record 25 of Set 3 | simpang
# Processing Record 26 of Set 3 | palu
# Processing Record 27 of Set 3 | katsuura
# Processing Record 28 of Set 3 | pisco
# Processing Record 29 of Set 3 | faanui
# Processing Record 30 of Set 3 | hami
# Processing Record 31 of Set 3 | muros
# Processing Record 32 of Set 3 | labrea
# Processing Record 33 of Set 3 | east london
# Processing Record 34 of Set 3 | rantauprapat
# Processing Record 35 of Set 3 | constitucion
# Processing Record 36 of Set 3 | chagda
# City not found...
# Processing Record 37 of Set 3 | puerto baquerizo moreno
# Processing Record 38 of Set 3 | nizhneyansk
# City not found...
# Processing Record 39 of Set 3 | cururupu
# Processing Record 40 of Set 3 | skibbereen
# Processing Record 41 of Set 3 | ouadda
# Processing Record 42 of Set 3 | umzimvubu
# City not found...
# Processing Record 43 of Set 3 | destin
# Processing Record 44 of Set 3 | teyateyaneng
# Processing Record 45 of Set 3 | margate
# Processing Record 46 of Set 3 | madimba
# Processing Record 47 of Set 3 | griffith
# Processing Record 48 of Set 3 | werda
# Processing Record 49 of Set 3 | illoqqortoormiut
# City not found...
# Processing Record 50 of Set 3 | svetlogorsk
# Processing Record 1 of Set 4 | albany
# Processing Record 2 of Set 4 | bandar-e torkaman
# City not found...
# Processing Record 3 of Set 4 | weiser
# Processing Record 4 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 4 | marcona
# City not found...
# Processing Record 6 of Set 4 | airai
# Processing Record 7 of Set 4 | hasaki
# Processing Record 8 of Set 4 | maracaju
# Processing Record 9 of Set 4 | guanica
# Processing Record 10 of Set 4 | humaita
# Processing Record 11 of Set 4 | limbang
# Processing Record 12 of Set 4 | hot springs
# Processing Record 13 of Set 4 | ponta do sol
# Processing Record 14 of Set 4 | saleaula
# City not found...
# Processing Record 15 of Set 4 | tasiilaq
# Processing Record 16 of Set 4 | leh
# Processing Record 17 of Set 4 | necochea
# Processing Record 18 of Set 4 | banff
# Processing Record 19 of Set 4 | marsa matruh
# Processing Record 20 of Set 4 | anadyr
# Processing Record 21 of Set 4 | vohibinany
# Processing Record 22 of Set 4 | coracao de jesus
# Processing Record 23 of Set 4 | ambilobe
# Processing Record 24 of Set 4 | gizo
# Processing Record 25 of Set 4 | vestmannaeyjar
# Processing Record 26 of Set 4 | tumannyy
# City not found...
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | mar del plata
# Processing Record 29 of Set 4 | stepnyak
# Processing Record 30 of Set 4 | paoua
# Processing Record 31 of Set 4 | hofn
# Processing Record 32 of Set 4 | prince rupert
# Processing Record 33 of Set 4 | zapolyarnyy
# Processing Record 34 of Set 4 | grand river south east
# City not found...
# Processing Record 35 of Set 4 | kappeln
# Processing Record 36 of Set 4 | la ronge
# Processing Record 37 of Set 4 | raga
# Processing Record 38 of Set 4 | grindavik
# Processing Record 39 of Set 4 | merke
# Processing Record 40 of Set 4 | port hedland
# Processing Record 41 of Set 4 | kareli
# Processing Record 42 of Set 4 | salamiyah
# Processing Record 43 of Set 4 | new norfolk
# Processing Record 44 of Set 4 | ostrovnoy
# Processing Record 45 of Set 4 | iqaluit
# Processing Record 46 of Set 4 | barentsburg
# City not found...
# Processing Record 47 of Set 4 | hendek
# Processing Record 48 of Set 4 | attawapiskat
# City not found...
# Processing Record 49 of Set 4 | kourou
# Processing Record 50 of Set 4 | kodino
# Processing Record 1 of Set 5 | veshenskaya
# Processing Record 2 of Set 5 | port macquarie
# Processing Record 3 of Set 5 | vaitupu
# City not found...
# Processing Record 4 of Set 5 | bad orb
# Processing Record 5 of Set 5 | kushima
# Processing Record 6 of Set 5 | barahona
# Processing Record 7 of Set 5 | belushya guba
# City not found...
# Processing Record 8 of Set 5 | tautira
# Processing Record 9 of Set 5 | matara
# Processing Record 10 of Set 5 | shatura
# Processing Record 11 of Set 5 | coihaique
# Processing Record 12 of Set 5 | miraflores
# Processing Record 13 of Set 5 | monywa
# Processing Record 14 of Set 5 | san quintin
# Processing Record 15 of Set 5 | verkh-usugli
# Processing Record 16 of Set 5 | ihosy
# Processing Record 17 of Set 5 | san ramon
# Processing Record 18 of Set 5 | akyab
# Processing Record 19 of Set 5 | esperance
# Processing Record 20 of Set 5 | itoman
# Processing Record 21 of Set 5 | samalaeulu
# City not found...
# Processing Record 22 of Set 5 | half moon bay
# Processing Record 23 of Set 5 | port-gentil
# Processing Record 24 of Set 5 | palabuhanratu
# City not found...
# Processing Record 25 of Set 5 | palmer
# Processing Record 26 of Set 5 | college
# Processing Record 27 of Set 5 | morondava
# Processing Record 28 of Set 5 | ulaangom
# Processing Record 29 of Set 5 | ewa beach
# Processing Record 30 of Set 5 | quang ngai
# Processing Record 31 of Set 5 | kuche
# City not found...
# Processing Record 32 of Set 5 | omboue
# Processing Record 33 of Set 5 | kaura namoda
# Processing Record 34 of Set 5 | saldanha
# Processing Record 35 of Set 5 | lusambo
# Processing Record 36 of Set 5 | hualmay
# Processing Record 37 of Set 5 | yemelyanovo
# Processing Record 38 of Set 5 | bonavista
# Processing Record 39 of Set 5 | doha
# Processing Record 40 of Set 5 | meyungs
# City not found...
# Processing Record 41 of Set 5 | kununurra
# Processing Record 42 of Set 5 | bud
# Processing Record 43 of Set 5 | bengkulu
# Processing Record 44 of Set 5 | ahuimanu
# Processing Record 45 of Set 5 | buala
# Processing Record 46 of Set 5 | krasnoselkup
# Processing Record 47 of Set 5 | sisimiut
# Processing Record 48 of Set 5 | synya
# Processing Record 49 of Set 5 | gardabani
# Processing Record 50 of Set 5 | tukan
# Processing Record 1 of Set 6 | thinadhoo
# Processing Record 2 of Set 6 | nome
# Processing Record 3 of Set 6 | puerto leguizamo
# Processing Record 4 of Set 6 | amahai
# Processing Record 5 of Set 6 | coquimbo
# Processing Record 6 of Set 6 | vestmanna
# Processing Record 7 of Set 6 | torbay
# Processing Record 8 of Set 6 | moerai
# Processing Record 9 of Set 6 | moose factory
# Processing Record 10 of Set 6 | finschhafen
# Processing Record 11 of Set 6 | crotone
# Processing Record 12 of Set 6 | antofagasta
# Processing Record 13 of Set 6 | namibe
# Processing Record 14 of Set 6 | formosa do rio preto
# Processing Record 15 of Set 6 | khasan
# Processing Record 16 of Set 6 | dunedin
# Processing Record 17 of Set 6 | aleksandrov gay
# Processing Record 18 of Set 6 | ilulissat
# Processing Record 19 of Set 6 | hohhot
# Processing Record 20 of Set 6 | alofi
# Processing Record 21 of Set 6 | acapulco
# Processing Record 22 of Set 6 | bodden town
# Processing Record 23 of Set 6 | ixtapa
# Processing Record 24 of Set 6 | kavieng
# Processing Record 25 of Set 6 | mitsamiouli
# Processing Record 26 of Set 6 | anloga
# Processing Record 27 of Set 6 | narsaq
# Processing Record 28 of Set 6 | santa cruz del sur
# Processing Record 29 of Set 6 | saskylakh
# Processing Record 30 of Set 6 | iquitos
# Processing Record 31 of Set 6 | vinh
# Processing Record 32 of Set 6 | chuguyevka
# Processing Record 33 of Set 6 | tuy hoa
# Processing Record 34 of Set 6 | anahuac
# Processing Record 35 of Set 6 | pacific grove
# Processing Record 36 of Set 6 | iznoski
# Processing Record 37 of Set 6 | berlevag
# Processing Record 38 of Set 6 | bulancak
# Processing Record 39 of Set 6 | barra do garcas
# Processing Record 40 of Set 6 | katy
# Processing Record 41 of Set 6 | ust-uda
# Processing Record 42 of Set 6 | kodiak
# Processing Record 43 of Set 6 | kieta
# Processing Record 44 of Set 6 | mirina
# City not found...
# Processing Record 45 of Set 6 | chokurdakh
# Processing Record 46 of Set 6 | namie
# Processing Record 47 of Set 6 | saint-philippe
# Processing Record 48 of Set 6 | kahului
# Processing Record 49 of Set 6 | kulachi
# Processing Record 50 of Set 6 | georgetown
# Processing Record 1 of Set 7 | fougamou
# Processing Record 2 of Set 7 | pitea
# Processing Record 3 of Set 7 | sorland
# Processing Record 4 of Set 7 | sitka
# Processing Record 5 of Set 7 | broken hill
# Processing Record 6 of Set 7 | dali
# Processing Record 7 of Set 7 | laguna
# Processing Record 8 of Set 7 | lorengau
# Processing Record 9 of Set 7 | rafraf
# Processing Record 10 of Set 7 | poum
# Processing Record 11 of Set 7 | samarai
# Processing Record 12 of Set 7 | ishigaki
# Processing Record 13 of Set 7 | gympie
# Processing Record 14 of Set 7 | ampanihy
# Processing Record 15 of Set 7 | ruatoria
# City not found...
# Processing Record 16 of Set 7 | tambacounda
# Processing Record 17 of Set 7 | sokoni
# Processing Record 18 of Set 7 | komsomolskiy
# Processing Record 19 of Set 7 | monchegorsk
# Processing Record 20 of Set 7 | matay
# Processing Record 21 of Set 7 | lavrentiya
# Processing Record 22 of Set 7 | sambava
# Processing Record 23 of Set 7 | abnub
# Processing Record 24 of Set 7 | mayo
# Processing Record 25 of Set 7 | norman wells
# Processing Record 26 of Set 7 | champerico
# Processing Record 27 of Set 7 | riyadh
# Processing Record 28 of Set 7 | alta floresta
# Processing Record 29 of Set 7 | barranca
# Processing Record 30 of Set 7 | saint-paul
# Processing Record 31 of Set 7 | nisia floresta
# Processing Record 32 of Set 7 | road town
# Processing Record 33 of Set 7 | macenta
# Processing Record 34 of Set 7 | deloraine
# Processing Record 35 of Set 7 | naze
# Processing Record 36 of Set 7 | tekeli
# Processing Record 37 of Set 7 | severo-kurilsk
# Processing Record 38 of Set 7 | comodoro rivadavia
# Processing Record 39 of Set 7 | takoradi
# Processing Record 40 of Set 7 | dibaya
# City not found...
# Processing Record 41 of Set 7 | padang
# Processing Record 42 of Set 7 | biak
# Processing Record 43 of Set 7 | san patricio
# Processing Record 44 of Set 7 | alegrete
# Processing Record 45 of Set 7 | sitio novo do tocantins
# Processing Record 46 of Set 7 | thunder bay
# Processing Record 47 of Set 7 | vaitape
# Processing Record 48 of Set 7 | constantine
# Processing Record 49 of Set 7 | nguiu
# City not found...
# Processing Record 50 of Set 7 | tinskoy
# Processing Record 1 of Set 8 | vertientes
# Processing Record 2 of Set 8 | srednekolymsk
# Processing Record 3 of Set 8 | anchorage
# Processing Record 4 of Set 8 | sur
# Processing Record 5 of Set 8 | bairiki
# Processing Record 6 of Set 8 | miri
# Processing Record 7 of Set 8 | guerrero negro
# Processing Record 8 of Set 8 | taree
# Processing Record 9 of Set 8 | myre
# Processing Record 10 of Set 8 | saint george
# Processing Record 11 of Set 8 | luderitz
# Processing Record 12 of Set 8 | qarchi gak
# Processing Record 13 of Set 8 | maua
# Processing Record 14 of Set 8 | tomatlan
# Processing Record 15 of Set 8 | marquette
# Processing Record 16 of Set 8 | borama
# City not found...
# Processing Record 17 of Set 8 | souillac
# Processing Record 18 of Set 8 | port-cartier
# Processing Record 19 of Set 8 | nelson bay
# Processing Record 20 of Set 8 | assiniboia
# Processing Record 21 of Set 8 | sampit
# Processing Record 22 of Set 8 | amderma
# City not found...
# Processing Record 23 of Set 8 | durban
# Processing Record 24 of Set 8 | karamea
# City not found...
# Processing Record 25 of Set 8 | nkhotakota
# Processing Record 26 of Set 8 | yako
# Processing Record 27 of Set 8 | sterling
# Processing Record 28 of Set 8 | santa cruz de tenerife
# Processing Record 29 of Set 8 | bagasara
# City not found...
# Processing Record 30 of Set 8 | yulara
# Processing Record 31 of Set 8 | bogovarovo
# Processing Record 32 of Set 8 | novo aripuana
# Processing Record 33 of Set 8 | dongzhen
# Processing Record 34 of Set 8 | lolua
# City not found...
# Processing Record 35 of Set 8 | cockburn town
# Processing Record 36 of Set 8 | goleta
# Processing Record 37 of Set 8 | urdzhar
# City not found...
# Processing Record 38 of Set 8 | genhe
# Processing Record 39 of Set 8 | wamba
# Processing Record 40 of Set 8 | hobyo
# Processing Record 41 of Set 8 | tunduru
# City not found...
# Processing Record 42 of Set 8 | macapa
# Processing Record 43 of Set 8 | kijang
# Processing Record 44 of Set 8 | ancud
# Processing Record 45 of Set 8 | bargal
# City not found...
# Processing Record 46 of Set 8 | port blair
# Processing Record 47 of Set 8 | concordia
# Processing Record 48 of Set 8 | la palma
# Processing Record 49 of Set 8 | novoagansk
# Processing Record 50 of Set 8 | tsihombe
# City not found...
# Processing Record 1 of Set 9 | bourail
# Processing Record 2 of Set 9 | berdsk
# Processing Record 3 of Set 9 | safakulevo
# Processing Record 4 of Set 9 | itapolis
# Processing Record 5 of Set 9 | emba
# Processing Record 6 of Set 9 | pangnirtung
# Processing Record 7 of Set 9 | mrirt
# City not found...
# Processing Record 8 of Set 9 | brigantine
# Processing Record 9 of Set 9 | nizwa
# Processing Record 10 of Set 9 | saint-francois
# Processing Record 11 of Set 9 | atar
# Processing Record 12 of Set 9 | beaupre
# Processing Record 13 of Set 9 | camacha
# Processing Record 14 of Set 9 | mount gambier
# Processing Record 15 of Set 9 | rajapur
# Processing Record 16 of Set 9 | cristalina
# Processing Record 17 of Set 9 | colares
# Processing Record 18 of Set 9 | leningradskiy
# Processing Record 19 of Set 9 | mys shmidta
# City not found...
# Processing Record 20 of Set 9 | puerto escondido
# Processing Record 21 of Set 9 | frederick
# Processing Record 22 of Set 9 | clyde river
# Processing Record 23 of Set 9 | samfya
# Processing Record 24 of Set 9 | oranjemund
# Processing Record 25 of Set 9 | brae
# Processing Record 26 of Set 9 | santiago de cao
# Processing Record 27 of Set 9 | chegdomyn
# Processing Record 28 of Set 9 | sencha
# Processing Record 29 of Set 9 | kloulklubed
# Processing Record 30 of Set 9 | vallenar
# Processing Record 31 of Set 9 | qaqortoq
# Processing Record 32 of Set 9 | saint-pierre
# Processing Record 33 of Set 9 | lanxi
# Processing Record 34 of Set 9 | priiskovyy
# Processing Record 35 of Set 9 | tucupita
# Processing Record 36 of Set 9 | general roca
# Processing Record 37 of Set 9 | afyonkarahisar
# Processing Record 38 of Set 9 | talnakh
# Processing Record 39 of Set 9 | fairbanks
# Processing Record 40 of Set 9 | senmonorom
# City not found...
# Processing Record 41 of Set 9 | gelemso
# Processing Record 42 of Set 9 | zhezkazgan
# Processing Record 43 of Set 9 | gibara
# Processing Record 44 of Set 9 | adrar
# Processing Record 45 of Set 9 | codrington
# Processing Record 46 of Set 9 | banjar
# Processing Record 47 of Set 9 | sept-iles
# Processing Record 48 of Set 9 | husavik
# Processing Record 49 of Set 9 | mattru
# Processing Record 50 of Set 9 | harrismith
# Processing Record 1 of Set 10 | port keats
# Processing Record 2 of Set 10 | alenquer
# Processing Record 3 of Set 10 | korla
# Processing Record 4 of Set 10 | wucheng
# Processing Record 5 of Set 10 | zhaodong
# Processing Record 6 of Set 10 | swan hill
# Processing Record 7 of Set 10 | anori
# Processing Record 8 of Set 10 | lincoln
# Processing Record 9 of Set 10 | makakilo city
# Processing Record 10 of Set 10 | santa marta
# Processing Record 11 of Set 10 | havelock
# Processing Record 12 of Set 10 | tilichiki
# Processing Record 13 of Set 10 | oktyabrskoye
# Processing Record 14 of Set 10 | westerstede
# Processing Record 15 of Set 10 | kuah
# Processing Record 16 of Set 10 | jinchang
# Processing Record 17 of Set 10 | keti bandar
# Processing Record 18 of Set 10 | fare
# Processing Record 19 of Set 10 | rabak
# Processing Record 20 of Set 10 | heiligenhafen
# Processing Record 21 of Set 10 | atherton
# Processing Record 22 of Set 10 | moranbah
# Processing Record 23 of Set 10 | burica
# City not found...
# Processing Record 24 of Set 10 | tabuk
# Processing Record 25 of Set 10 | egvekinot
# Processing Record 26 of Set 10 | sechura
# Processing Record 27 of Set 10 | yeppoon
# Processing Record 28 of Set 10 | sinkat
# City not found...
# Processing Record 29 of Set 10 | meulaboh
# Processing Record 30 of Set 10 | bardiyah
# Processing Record 31 of Set 10 | dzhusaly
# City not found...
# Processing Record 32 of Set 10 | buon me thuot
# City not found...
# Processing Record 33 of Set 10 | torata
# Processing Record 34 of Set 10 | cayenne
# Processing Record 35 of Set 10 | luau
# Processing Record 36 of Set 10 | slantsy
# Processing Record 37 of Set 10 | bethanien
# Processing Record 38 of Set 10 | karpuninskiy
# City not found...
# Processing Record 39 of Set 10 | lufilufi
# Processing Record 40 of Set 10 | birjand
# Processing Record 41 of Set 10 | the valley
# Processing Record 42 of Set 10 | port dover
# Processing Record 43 of Set 10 | zyryanka
# Processing Record 44 of Set 10 | kenai
# Processing Record 45 of Set 10 | ossett
# Processing Record 46 of Set 10 | yarmouth
# Processing Record 47 of Set 10 | fort nelson
# Processing Record 48 of Set 10 | morehead
# Processing Record 49 of Set 10 | cidreira
# Processing Record 50 of Set 10 | chelmno
# Processing Record 1 of Set 11 | bekhtery
# Processing Record 2 of Set 11 | esterhazy
# Processing Record 3 of Set 11 | monte santo de minas
# Processing Record 4 of Set 11 | kolhapur
# Processing Record 5 of Set 11 | yirol
# City not found...
# Processing Record 6 of Set 11 | huilong
# Processing Record 7 of Set 11 | carmelo
# Processing Record 8 of Set 11 | indramayu
# Processing Record 9 of Set 11 | kavaratti
# Processing Record 10 of Set 11 | kangaatsiaq
# Processing Record 11 of Set 11 | butzbach
# Processing Record 12 of Set 11 | plettenberg bay
# Processing Record 13 of Set 11 | golden
# Processing Record 14 of Set 11 | broome
# Processing Record 15 of Set 11 | himatangi
# Processing Record 16 of Set 11 | karaul
# City not found...
# Processing Record 17 of Set 11 | pundaguitan
# Processing Record 18 of Set 11 | luocheng
# Processing Record 19 of Set 11 | coos bay
# Processing Record 20 of Set 11 | oyama
# Processing Record 21 of Set 11 | menomonie
# Processing Record 22 of Set 11 | qui nhon
# Processing Record 23 of Set 11 | sangar
# Processing Record 24 of Set 11 | iisalmi
# Processing Record 25 of Set 11 | hervey bay
# Processing Record 26 of Set 11 | bosaso
# Processing Record 27 of Set 11 | olafsvik
# Processing Record 28 of Set 11 | shingu
# Processing Record 29 of Set 11 | sulangan
# Processing Record 30 of Set 11 | annau
# Processing Record 31 of Set 11 | karatau
# Processing Record 32 of Set 11 | kanniyakumari
# Processing Record 33 of Set 11 | innisfail
# Processing Record 34 of Set 11 | liwale
# Processing Record 35 of Set 11 | zaranj
# Processing Record 36 of Set 11 | igarka
# Processing Record 37 of Set 11 | visby
# Processing Record 38 of Set 11 | trofors
# Processing Record 39 of Set 11 | amazar
# Processing Record 40 of Set 11 | sinnamary
# Processing Record 41 of Set 11 | chapais
# Processing Record 42 of Set 11 | hailun
# Processing Record 43 of Set 11 | waitara
# Processing Record 44 of Set 11 | miyako
# Processing Record 45 of Set 11 | chimoio
# Processing Record 46 of Set 11 | tiquisate
# Processing Record 47 of Set 11 | aripuana
# Processing Record 48 of Set 11 | sola
# Processing Record 49 of Set 11 | lypova dolyna
# Processing Record 50 of Set 11 | puri
# Processing Record 1 of Set 12 | songea
# Processing Record 2 of Set 12 | eyl
# Processing Record 3 of Set 12 | jalingo
# Processing Record 4 of Set 12 | kharan
# Processing Record 5 of Set 12 | mahon
# Processing Record 6 of Set 12 | ahmadnagar
# Processing Record 7 of Set 12 | kangshan
# Processing Record 8 of Set 12 | jalgaon
# Processing Record 9 of Set 12 | tarko-sale
# Processing Record 10 of Set 12 | formoso do araguaia
# City not found...
# Processing Record 11 of Set 12 | borazjan
# Processing Record 12 of Set 12 | bushehr
# Processing Record 13 of Set 12 | kolo
# Processing Record 14 of Set 12 | zhigansk
# Processing Record 15 of Set 12 | azoyu
# Processing Record 16 of Set 12 | aswan
# Processing Record 17 of Set 12 | klaksvik
# Processing Record 18 of Set 12 | pochutla
# Processing Record 19 of Set 12 | koundara
# Processing Record 20 of Set 12 | vite
# Processing Record 21 of Set 12 | guane
# Processing Record 22 of Set 12 | shimoda
# Processing Record 23 of Set 12 | never
# Processing Record 24 of Set 12 | sentyabrskiy
# City not found...
# Processing Record 25 of Set 12 | bereznik
# Processing Record 26 of Set 12 | baherden
# Processing Record 27 of Set 12 | muli
# Processing Record 28 of Set 12 | ures
# Processing Record 29 of Set 12 | port hardy
# Processing Record 30 of Set 12 | tessalit
# Processing Record 31 of Set 12 | sasni
# Processing Record 32 of Set 12 | pio duran
# Processing Record 33 of Set 12 | kamenskoye
# City not found...
# Processing Record 34 of Set 12 | tena
# Processing Record 35 of Set 12 | flinders
# Processing Record 36 of Set 12 | kushiro
# Processing Record 37 of Set 12 | luena
# Processing Record 38 of Set 12 | kadykchan
# City not found...
# Processing Record 39 of Set 12 | ranau
# Processing Record 40 of Set 12 | katobu
# Processing Record 41 of Set 12 | elat
# Processing Record 42 of Set 12 | kasongo-lunda
# Processing Record 43 of Set 12 | zarichne
# Processing Record 44 of Set 12 | ust-nera
# Processing Record 45 of Set 12 | whyalla
# Processing Record 46 of Set 12 | baykit
# Processing Record 47 of Set 12 | strezhevoy
# Processing Record 48 of Set 12 | san cristobal
# Processing Record 49 of Set 12 | lakes entrance
# Processing Record 50 of Set 12 | kalmunai
# Processing Record 1 of Set 13 | nabire
# Processing Record 2 of Set 13 | lompoc
# Processing Record 3 of Set 13 | mana
# Processing Record 4 of Set 13 | bhatkal
# Processing Record 5 of Set 13 | whitehorse
# Processing Record 6 of Set 13 | keene
# Processing Record 7 of Set 13 | pandan
# Processing Record 8 of Set 13 | solnechnyy
# Processing Record 9 of Set 13 | pahrump
# Processing Record 10 of Set 13 | hay river
# Processing Record 11 of Set 13 | makinsk
# Processing Record 12 of Set 13 | kedrovyy
# Processing Record 13 of Set 13 | lesnoye
# Processing Record 14 of Set 13 | siguiri
# Processing Record 15 of Set 13 | yar-sale
# Processing Record 16 of Set 13 | ipixuna
# Processing Record 17 of Set 13 | tamazulapam
# City not found...
# Processing Record 18 of Set 13 | svetlyy
# Processing Record 19 of Set 13 | yialos
# City not found...
# Processing Record 20 of Set 13 | bereda
# Processing Record 21 of Set 13 | rio gallegos
# Processing Record 22 of Set 13 | atambua
# Processing Record 23 of Set 13 | suhut
# Processing Record 24 of Set 13 | grand island
# Processing Record 25 of Set 13 | erenhot
# Processing Record 26 of Set 13 | louisbourg
# City not found...
# Processing Record 27 of Set 13 | colonia
# Processing Record 28 of Set 13 | manicore
# Processing Record 29 of Set 13 | sao filipe
# Processing Record 30 of Set 13 | mackay
# Processing Record 31 of Set 13 | beringovskiy
# Processing Record 32 of Set 13 | pirgos
# Processing Record 33 of Set 13 | la asuncion
# Processing Record 34 of Set 13 | pingliang
# Processing Record 35 of Set 13 | ngukurr
# City not found...
# Processing Record 36 of Set 13 | labuan
# Processing Record 37 of Set 13 | oume
# Processing Record 38 of Set 13 | vitim
# Processing Record 39 of Set 13 | deer lake
# Processing Record 40 of Set 13 | mariental
# Processing Record 41 of Set 13 | juneau
# Processing Record 42 of Set 13 | acajutla
# Processing Record 43 of Set 13 | lai
# Processing Record 44 of Set 13 | mumford
# Processing Record 45 of Set 13 | tsienyane
# City not found...
# Processing Record 46 of Set 13 | jacareacanga
# Processing Record 47 of Set 13 | dingle
# Processing Record 48 of Set 13 | richards bay
# Processing Record 49 of Set 13 | changtu
# Processing Record 50 of Set 13 | rawannawi
# City not found...
# Processing Record 1 of Set 14 | dzilam gonzalez
# Processing Record 2 of Set 14 | puerto madero
# Processing Record 3 of Set 14 | pervomayskoye
# Processing Record 4 of Set 14 | swan river
# Processing Record 5 of Set 14 | santa ines
# Processing Record 6 of Set 14 | tambura
# Processing Record 7 of Set 14 | chimbarongo
# Processing Record 8 of Set 14 | camana
# Processing Record 9 of Set 14 | cedro
# Processing Record 10 of Set 14 | warqla
# City not found...
# Processing Record 11 of Set 14 | rio grande
# Processing Record 12 of Set 14 | pangai
# Processing Record 13 of Set 14 | umm lajj
# Processing Record 14 of Set 14 | abomey
# Processing Record 15 of Set 14 | cam ranh
# Processing Record 16 of Set 14 | paamiut
# Processing Record 17 of Set 14 | suao
# City not found...
# Processing Record 18 of Set 14 | paracatu
# Processing Record 19 of Set 14 | sambhal
# Processing Record 20 of Set 14 | burnie
# Processing Record 21 of Set 14 | nishihara
# Processing Record 22 of Set 14 | portel
# Processing Record 23 of Set 14 | dubbo
# Processing Record 24 of Set 14 | mabaruma
# Processing Record 25 of Set 14 | soyo
# Processing Record 26 of Set 14 | verkhnevilyuysk
# Processing Record 27 of Set 14 | torrevieja
# Processing Record 28 of Set 14 | kokopo
# Processing Record 29 of Set 14 | nha trang
# Processing Record 30 of Set 14 | noumea
# Processing Record 31 of Set 14 | funtua
# Processing Record 32 of Set 14 | fomboni
# Processing Record 33 of Set 14 | mingshui
# Processing Record 34 of Set 14 | oistins
# Processing Record 35 of Set 14 | vao
# Processing Record 36 of Set 14 | paita
# Processing Record 37 of Set 14 | baruun-urt
# Processing Record 38 of Set 14 | talcahuano
# Processing Record 39 of Set 14 | marinette
# Processing Record 40 of Set 14 | tutoia
# Processing Record 41 of Set 14 | touros
# Processing Record 42 of Set 14 | plouzane
# Processing Record 43 of Set 14 | abu dhabi
# Processing Record 44 of Set 14 | hebi
# Processing Record 45 of Set 14 | miragoane
# Processing Record 46 of Set 14 | kapuskasing
# Processing Record 47 of Set 14 | kodar
# Processing Record 48 of Set 14 | port said
# Processing Record 49 of Set 14 | bichura
# Processing Record 50 of Set 14 | burns lake
# Processing Record 1 of Set 15 | mehamn
# Processing Record 2 of Set 15 | idenao
# Processing Record 3 of Set 15 | tinyahuarco
# Processing Record 4 of Set 15 | jefferson city
# Processing Record 5 of Set 15 | bilibino
# Processing Record 6 of Set 15 | quatre cocos
# Processing Record 7 of Set 15 | barbar
# City not found...
# Processing Record 8 of Set 15 | shenjiamen
# Processing Record 9 of Set 15 | belaya gora
# Processing Record 10 of Set 15 | anar darreh
# City not found...
# Processing Record 11 of Set 15 | itarema
# Processing Record 12 of Set 15 | sukumo
# Processing Record 13 of Set 15 | novyy urengoy
# Processing Record 14 of Set 15 | cornelius
# Processing Record 15 of Set 15 | york
# Processing Record 16 of Set 15 | grong
# Processing Record 17 of Set 15 | viedma
# Processing Record 18 of Set 15 | avera
# Processing Record 19 of Set 15 | yumen
# Processing Record 20 of Set 15 | saryshagan
# City not found...
# Processing Record 21 of Set 15 | lasa
# Processing Record 22 of Set 15 | gorontalo
# Processing Record 23 of Set 15 | bubaque
# Processing Record 24 of Set 15 | nizhniy ufaley
# Processing Record 25 of Set 15 | de aar
# Processing Record 26 of Set 15 | mizpe ramon
# City not found...
# Processing Record 27 of Set 15 | pasni
# Processing Record 28 of Set 15 | kimbe
# Processing Record 29 of Set 15 | cap malheureux
# Processing Record 30 of Set 15 | forio
# Processing Record 31 of Set 15 | grand-santi
# Processing Record 32 of Set 15 | bugene
# Processing Record 33 of Set 15 | severomuysk
# Processing Record 34 of Set 15 | gorom-gorom
# Processing Record 35 of Set 15 | butte
# Processing Record 36 of Set 15 | punta alta
# Processing Record 37 of Set 15 | lodja
# Processing Record 38 of Set 15 | chkalovskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 678

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Tiksi  71.6872  128.8694    -27.69       100         100
# 1          Mataura -46.1927  168.8643     62.49        71           9
# 2             Hilo  19.7297 -155.0900     78.01        73           0
# 3  Bambous Virieux -20.3428   57.7575     80.85        83          75
# 4         Hamilton  39.1834  -84.5333     48.25        73          75
# 5          Ushuaia -54.8000  -68.3000     62.26        51          75
# 6      Nortelandia -14.4547  -56.8028     89.76        49          95
# 7          Rikitea -23.1203 -134.9692     77.63        71          55
# 8            Seoul  37.5683  126.9778     24.24        81           0
# 9        Gushikawa  26.3544  127.8686     60.03        63         100
#
#    Wind Speed Country Current Description
# 0        0.67      RU     overcast clouds
# 1        1.34      NZ           clear sky
# 2        5.99      US           clear sky
# 3       18.41      MU       moderate rain
# 4        3.44      US       moderate rain
# 5       17.27      AR       broken clouds
# 6        3.00      BR     overcast clouds
# 7        3.42      PF       broken clouds
# 8        1.14      KR           clear sky
# 9        4.61      JP     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
#Reorder

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Tiksi      RU  71.6872  128.8694    -27.69       100         100
# 1          Mataura      NZ -46.1927  168.8643     62.49        71           9
# 2             Hilo      US  19.7297 -155.0900     78.01        73           0
# 3  Bambous Virieux      MU -20.3428   57.7575     80.85        83          75
# 4         Hamilton      US  39.1834  -84.5333     48.25        73          75
# 5          Ushuaia      AR -54.8000  -68.3000     62.26        51          75
# 6      Nortelandia      BR -14.4547  -56.8028     89.76        49          95
# 7          Rikitea      PF -23.1203 -134.9692     77.63        71          55
# 8            Seoul      KR  37.5683  126.9778     24.24        81           0
# 9        Gushikawa      JP  26.3544  127.8686     60.03        63         100
#
#    Wind Speed Current Description
# 0        0.67     overcast clouds
# 1        1.34           clear sky
# 2        5.99           clear sky
# 3       18.41       moderate rain
# 4        3.44       moderate rain
# 5       17.27       broken clouds
# 6        3.00     overcast clouds
# 7        3.42       broken clouds
# 8        1.14           clear sky
# 9        4.61     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City ID")
